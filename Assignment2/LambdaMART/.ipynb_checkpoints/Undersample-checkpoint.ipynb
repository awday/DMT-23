# %%
import pandas as pd
import numpy as np
import random

from sklearn.model_selection import train_test_split

# Function to sample queries
def sample_queries(df, frac):
    srch_ids = pd.Series(df["srch_id"].unique()).sample(frac=frac, random_state=42)
    return df.loc[df.srch_id.isin(srch_ids)]

in_train = pd.read_csv("data/training_set_VU_DM_2014.csv")
#in_test = pd.read_csv("data/testing_set_VU_DM_2014.csv")
#in_test = pd.read_csv("data/kaggle_test.csv")
in_test = in_train.drop(["click_bool", "booking_bool", "position", "gross_bookings_usd"], axis=1).head(n=0)

# Speed up execution
#in_train = sample_queries(in_train, 0.1)

in_train.head()
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score      ...       comp6_rate_percent_diff  \
# 0                3                3.5      ...                           NaN
# 1                4                4.0      ...                           NaN
# 2                3                4.5      ...                           NaN
# 3                2                4.0      ...                           NaN
# 4                4                3.5      ...                           NaN
#
#    comp7_rate  comp7_inv  comp7_rate_percent_diff  comp8_rate  comp8_inv  \
# 0         NaN        NaN                      NaN         0.0        0.0
# 1         NaN        NaN                      NaN         0.0        0.0
# 2         NaN        NaN                      NaN         0.0        0.0
# 3         NaN        NaN                      NaN        -1.0        0.0
# 4         NaN        NaN                      NaN         0.0        0.0
#
#    comp8_rate_percent_diff  click_bool  gross_bookings_usd  booking_bool
# 0                      NaN           0                 NaN             0
# 1                      NaN           0                 NaN             0
# 2                      NaN           0                 NaN             0
# 3                      5.0           0                 NaN             0
# 4                      NaN           0                 NaN             0
#
# [5 rows x 54 columns]

# %%
# Add mean, median and std per property for a variety of numericals
def add_mean_median_std_per_factor(df, factor, numerical, prefix):
    grouped = df.groupby(factor)[numerical]
    mean_by_factor = grouped.mean().to_dict()
    median_by_factor = grouped.median().to_dict()
    std_by_factor = grouped.std().to_dict()
    
    df[prefix + "_mean_" + numerical] = df[factor].map(lambda f: mean_by_factor[f])
    df[prefix + "_median_" + numerical] = df[factor].map(lambda f: median_by_factor[f])
    df[prefix + "_std_" + numerical] = df[factor].map(lambda f: std_by_factor[f])
    
for df in [in_train, in_test]:
    f = add_mean_median_std_per_factor
    f(df, "srch_id", "price_usd", "srch")
    f(df, "srch_id", "prop_starrating", "srch")
    f(df, "srch_id", "prop_review_score", "srch")
    
    # These features don't seem to work well, keeping it in for now though
    f(df, "srch_destination_id", "price_usd", "dest")
    f(df, "srch_destination_id", "prop_starrating", "dest")
    f(df, "srch_destination_id", "prop_review_score", "dest")
    
    f(df, "prop_id", "price_usd", "prop")
    f(df, "prop_id", "prop_review_score", "prop")
    
in_train.head()

# %%
# Normalize price per factor
for df in [in_train, in_test]:
    df["price_norm_srch"] = df.groupby("srch_id").price_usd.transform(lambda x: (x - x.mean()) / x.std())
    df["price_norm_prop"] = df.groupby("prop_id").price_usd.transform(lambda x: (x - x.mean()) / x.std())
    df["price_norm_prop_srch"] = df.groupby("srch_id").price_norm_prop.transform(lambda x: (x - x.mean()) / x.std())

# %%
# Split on search ids
srch_ids = in_train["srch_id"].unique()
srch_ids_train, srch_ids_test_val = train_test_split(srch_ids, test_size=0.5, random_state = 42)
srch_ids_test, srch_ids_val = train_test_split(srch_ids_test_val, test_size=0.5, random_state = 42)

_train = in_train.loc[in_train.srch_id.isin(srch_ids_train)]
_val = in_train.loc[in_train.srch_id.isin(srch_ids_val)]
_test = in_train.loc[in_train.srch_id.isin(srch_ids_test)]

# %%
# Estimate probability of being clicked and booked
#grouped = _train.groupby("prop_id")    
#click_prob_by_prop = grouped.click_bool.mean().to_dict()
#book_prob_by_prop = grouped.booking_bool.mean().to_dict()

#mean_click_prob = in_train.click_bool.mean()
#mean_book_prob = in_train.booking_bool.mean()
    
#for df in [_train, _val, _test, in_test]:
#    df["click_probability"] = df.prop_id.map(lambda p: click_prob_by_prop.setdefault(p, mean_click_prob))
#    df["booking_probability"] = df.prop_id.map(lambda p: book_prob_by_prop.setdefault(p, mean_book_prob))

# %%
# Undersample a series so that there are as many non-clicked items as clicked and booked
def downsample_series(s):
    s1 = s.loc[s.click_bool == 1]
    s2 = s.loc[s.click_bool == 0]
    
    if (len(s2) == 0):
        return s1
    
    s2 = s2.sample(frac=min(1, len(s1)/len(s)))
    return s1.append(s2).sort_index()

_train_undersampled = _train.groupby("srch_id").apply(downsample_series).reset_index(drop=True)

# %%
# Save to CSV
#_train.to_csv("data/processed/_train.csv", index=False)
_val.to_csv("data/processed/_val.csv", index=False)
_test.to_csv("data/processed/_test.csv", index=False)
_train_undersampled.to_csv("data/processed/_train_undersampled.csv", index=False)
in_test.to_csv("data/processed/kaggle_test.csv", index=False)

# %%
in_test.head()

# %%
#pos_by_dest_prop = _train.groupby(["srch_destination_id", "prop_id"]).position.mean().to_dict()
#pos_by_prop = _train.groupby("prop_id").position.mean().to_dict()
#pos_by_dest = _train.groupby("srch_destination_id").position.mean().to_dict()

#total_mean_pos = _train.position.mean()

#def series_add_est_pos(s):
    # TODO: estimate position based on property and destination id

#_val.groupby(["prop_id", "srch_destination_id"]).apply(series_add_est_pos)
# Out:
# 4653476    3931
# Name: srch_destination_id, dtype: int64
# 4653476    3931
# Name: srch_destination_id, dtype: int64
# 160862     6475
# 201194     6475
# 455818     6475
# 602985     6475
# 849798     6475
# 1245901    6475
# 1304993    6475
# 1668432    6475
# 1941617    6475
# 2579011    6475
# 3180218    6475
# 3516642    6475
# 4269156    6475
# Name: srch_destination_id, dtype: int64
# 3550611    14215
# Name: srch_destination_id, dtype: int64
# 288598    20983
# Name: srch_destination_id, dtype: int64
# 2614309    1989
# Name: srch_destination_id, dtype: int64
# 1840347    617
# Name: srch_destination_id, dtype: int64
# 1229185    1472
# Name: srch_destination_id, dtype: int64
# 4102948    3480
# Name: srch_destination_id, dtype: int64
# 3052153    10494
# Name: srch_destination_id, dtype: int64
# 3657703    11008
# Name: srch_destination_id, dtype: int64
# 1836100    11381
# 3222963    11381
# 4482532    11381
# Name: srch_destination_id, dtype: int64
# 773131    12022
# Name: srch_destination_id, dtype: int64
# 1046820    14385
# Name: srch_destination_id, dtype: int64
# 542640    14397
# Name: srch_destination_id, dtype: int64
# 3597989    16776
# Name: srch_destination_id, dtype: int64
# 2528607    21467
# Name: srch_destination_id, dtype: int64
# 1332587    22730
# Name: srch_destination_id, dtype: int64
# 1039013    23313
# 1315948    23313
# 4935775    23313
# Name: srch_destination_id, dtype: int64
# 1994104    27155
# Name: srch_destination_id, dtype: int64
# 857710    27451
# Name: srch_destination_id, dtype: int64
# 279746     28030
# 1385733    28030
# 2765964    28030
# Name: srch_destination_id, dtype: int64
# 2217726    12631
# Name: srch_destination_id, dtype: int64
# 1241272    13292
# 3189239    13292
# Name: srch_destination_id, dtype: int64
# 1226253    15650
# 1384260    15650
# 2242299    15650
# 4341124    15650
# 4576263    15650
# Name: srch_destination_id, dtype: int64
# 2587323    26226
# Name: srch_destination_id, dtype: int64
# 769655     9392
# 846972     9392
# 1945747    9392
# Name: srch_destination_id, dtype: int64
# 3574329    28198
# Name: srch_destination_id, dtype: int64
# 4487771    7573
# Name: srch_destination_id, dtype: int64
# 2189695    22501
# Name: srch_destination_id, dtype: int64
# 347511     23495
# 4932864    23495
# Name: srch_destination_id, dtype: int64
# 476660    21079
# Name: srch_destination_id, dtype: int64
# 524614    21415
# 820429    21415
# Name: srch_destination_id, dtype: int64
# 80726      16624
# 630660     16624
# 2009401    16624
# 2260379    16624
# 2746280    16624
# Name: srch_destination_id, dtype: int64
# 4699094    20863
# Name: srch_destination_id, dtype: int64
# 4954859    20348
# Name: srch_destination_id, dtype: int64
# 9296       11308
# 166061     11308
# 610317     11308
# 1075906    11308
# 1579795    11308
# 2422114    11308
# 2529602    11308
# 2639190    11308
# 2905507    11308
# 2912006    11308
# 3666637    11308
# 3935630    11308
# 3939718    11308
# 4037706    11308
# 4136818    11308
# 4282884    11308
# 4287212    11308
# 4378199    11308
# 4731776    11308
# Name: srch_destination_id, dtype: int64
# 790666     14083
# 1291116    14083
# 1595687    14083
# 3121484    14083
# 3909620    14083
# 4753543    14083
# Name: srch_destination_id, dtype: int64
# 534727    22642
# Name: srch_destination_id, dtype: int64
# 2264348    23415
# Name: srch_destination_id, dtype: int64
# 518872    17464
# Name: srch_destination_id, dtype: int64
# 4204728    20730
# Name: srch_destination_id, dtype: int64
# 3568615    9371
# 4793527    9371
# Name: srch_destination_id, dtype: int64
# 3181414    22879
# 4807127    22879
# Name: srch_destination_id, dtype: int64
# 133263     27445
# 503945     27445
# 1519571    27445
# 1938952    27445
# 2121902    27445
# 2518206    27445
# 3966448    27445
# 4370832    27445
# 4850782    27445
# 4938373    27445
# Name: srch_destination_id, dtype: int64
# 326504     10247
# 695600     10247
# 1144170    10247
# 2923970    10247
# 3447717    10247
# 4347963    10247
# 4546645    10247
# Name: srch_destination_id, dtype: int64
# 145521     12016
# 397651     12016
# 2296530    12016
# Name: srch_destination_id, dtype: int64
# 4624164    25535
# Name: srch_destination_id, dtype: int64
# 624476    14330
# Name: srch_destination_id, dtype: int64
# 28865      19688
# 475699     19688
# 697989     19688
# 808840     19688
# 2292005    19688
# 2989227    19688
# 3252249    19688
# 3613281    19688
# 4356666    19688
# 4493534    19688
# 4583379    19688
# Name: srch_destination_id, dtype: int64
# 4198867    26772
# Name: srch_destination_id, dtype: int64
# 336352     27176
# 1435513    27176
# 2312266    27176
# 3036486    27176
# Name: srch_destination_id, dtype: int64
# 971929     1261
# 980053     1261
# 2060482    1261
# Name: srch_destination_id, dtype: int64
# 1250165    25423
# 4052047    25423
# Name: srch_destination_id, dtype: int64
# 345385     6106
# 1680640    6106
# 1858013    6106
# 3333669    6106
# Name: srch_destination_id, dtype: int64
# 1917752    11682
# 4912152    11682
# Name: srch_destination_id, dtype: int64
# 1936716    17232
# 2089668    17232
# 2097670    17232
# 2262337    17232
# 2264033    17232
# 3825170    17232
# 4942237    17232
# Name: srch_destination_id, dtype: int64
# 4146938    13728
# Name: srch_destination_id, dtype: int64
# 4296544    15909
# Name: srch_destination_id, dtype: int64
# 1227151    24443
# 2287196    24443
# Name: srch_destination_id, dtype: int64
# 1523226    12902
# 2533550    12902
# 3030199    12902
# 4105014    12902
# Name: srch_destination_id, dtype: int64
# 2617183    18501
# Name: srch_destination_id, dtype: int64
# 4043067    3992
# Name: srch_destination_id, dtype: int64
# 4589715    7443
# Name: srch_destination_id, dtype: int64
# 3105810    1618
# Name: srch_destination_id, dtype: int64
# 1606700    10867
# 1783874    10867
# 2066423    10867
# 2365731    10867
# 3900802    10867
# Name: srch_destination_id, dtype: int64
# 702791    15426
# Name: srch_destination_id, dtype: int64
# 3943       1742
# 41854      1742
# 412685     1742
# 1776380    1742
# 2003235    1742
# 2091091    1742
# 2194886    1742
# 2375109    1742
# 3479324    1742
# 4288266    1742
# 4401255    1742
# Name: srch_destination_id, dtype: int64
# 1934307    7571
# 2598076    7571
# Name: srch_destination_id, dtype: int64
# 1301240    11926
# 4615565    11926
# Name: srch_destination_id, dtype: int64
# 84152      12571
# 129570     12571
# 201480     12571
# 445619     12571
# 602922     12571
# 1052639    12571
# 1697164    12571
# 1707603    12571
# 1817263    12571
# 2114529    12571
# 2321499    12571
# 3264663    12571
# 3766290    12571
# 4360536    12571
# 4494084    12571
# Name: srch_destination_id, dtype: int64
# 2160243    16849
# 2377896    16849
# Name: srch_destination_id, dtype: int64
# 2365130    20140
# Name: srch_destination_id, dtype: int64
# 2460935    21702
# Name: srch_destination_id, dtype: int64
# 2832869    23278
# 2918640    23278
# Name: srch_destination_id, dtype: int64
# 4769818    26303
# Name: srch_destination_id, dtype: int64
# 1485439    16169
# Name: srch_destination_id, dtype: int64
# 135513     5317
# 2495271    5317
# 3198365    5317
# Name: srch_destination_id, dtype: int64
# 1965553    3919
# 3569989    3919
# Name: srch_destination_id, dtype: int64
# 231692     25614
# 662715     25614
# 1319392    25614
# 1343107    25614
# 1586744    25614
# 1883416    25614
# 2643731    25614
# 3082704    25614
# 3119650    25614
# 3295506    25614
# 3609249    25614
# 3886443    25614
# 4101074    25614
# 4395403    25614
# 4701989    25614
# Name: srch_destination_id, dtype: int64
# 1479369    26607
# Name: srch_destination_id, dtype: int64
# 2931605    27419
# Name: srch_destination_id, dtype: int64
# 4186913    4916
# Name: srch_destination_id, dtype: int64
# 3536643    6708
# Name: srch_destination_id, dtype: int64
# 980675     8909
# 1964285    8909
# 2714083    8909
# 3435859    8909
# Name: srch_destination_id, dtype: int64
# 268723    12788
# Name: srch_destination_id, dtype: int64
# 1261605    14014
# 1934466    14014
# 2098449    14014
# Name: srch_destination_id, dtype: int64
# 972131     22173
# 3485477    22173
# 3594906    22173
# 4372523    22173
# Name: srch_destination_id, dtype: int64
# 1940952    23571
# Name: srch_destination_id, dtype: int64
# 4181159    5149
# Name: srch_destination_id, dtype: int64
# 2408539    5249
# Name: srch_destination_id, dtype: int64
# 1524472    27958
# 1600636    27958
# Name: srch_destination_id, dtype: int64
# 2103084    15789
# 3555567    15789
# Name: srch_destination_id, dtype: int64
# 2099563    23840
# 4830325    23840
# 4849178    23840
# Name: srch_destination_id, dtype: int64
# 36646      26361
# 4294184    26361
# Name: srch_destination_id, dtype: int64
# 4234790    19193
# Name: srch_destination_id, dtype: int64
# 527612    27549
# Name: srch_destination_id, dtype: int64
# 2083122    1813
# Name: srch_destination_id, dtype: int64
# 1352503    16989
# 4742936    16989
# Name: srch_destination_id, dtype: int64
# 496252    21018
# Name: srch_destination_id, dtype: int64
# 2335550    24824
# Name: srch_destination_id, dtype: int64
# 1992073    11088
# 2026051    11088
# 2580252    11088
# Name: srch_destination_id, dtype: int64
# 516502    3847
# Name: srch_destination_id, dtype: int64
# 2139778    6111
# Name: srch_destination_id, dtype: int64
# 4373431    23663
# Name: srch_destination_id, dtype: int64
# 3716677    8202
# Name: srch_destination_id, dtype: int64
# 1361955    18968
# Name: srch_destination_id, dtype: int64
# 4892317    7255
# Name: srch_destination_id, dtype: int64
# 2054548    18774
# 2166385    18774
# 3764037    18774
# Name: srch_destination_id, dtype: int64
# 157584     24519
# 1896953    24519
# Name: srch_destination_id, dtype: int64
# 4707270    24737
# Name: srch_destination_id, dtype: int64
# 915487     13570
# 1703785    13570
# 1870095    13570
# 2247144    13570
# 2338167    13570
# 2584251    13570
# 2792318    13570
# 3376257    13570
# 3992166    13570
# Name: srch_destination_id, dtype: int64
# 3748347    21819
# Name: srch_destination_id, dtype: int64
# 3747295    6968
# Name: srch_destination_id, dtype: int64
# 4476463    17199
# Name: srch_destination_id, dtype: int64
# 2483702    25733
# 3440320    25733
# 3637056    25733
# 3668536    25733
# 4426937    25733
# Name: srch_destination_id, dtype: int64
# 675583     27425
# 1874432    27425
# 3631528    27425
# 3680294    27425
# 4238533    27425
# 4711478    27425
# Name: srch_destination_id, dtype: int64
# 417904     8186
# 1847333    8186
# Name: srch_destination_id, dtype: int64
# 655592     14167
# 1609903    14167
# 2223361    14167
# 2659999    14167
# Name: srch_destination_id, dtype: int64
# 837873     16570
# 1706783    16570
# 1754299    16570
# 1909457    16570
# 2345279    16570
# 2702507    16570
# 4253995    16570
# 4331921    16570
# 4494718    16570
# 4829404    16570
# 4840743    16570
# Name: srch_destination_id, dtype: int64
# 2729981    22393
# Name: srch_destination_id, dtype: int64
# 163088     27615
# 934965     27615
# 1716002    27615
# 2096408    27615
# 2424331    27615
# 3181698    27615
# 4025885    27615
# 4398518    27615
# 4648853    27615
# Name: srch_destination_id, dtype: int64
# 460078     17549
# 4941292    17549
# Name: srch_destination_id, dtype: int64
# 1943140    23769
# Name: srch_destination_id, dtype: int64
# 470359    24212
# Name: srch_destination_id, dtype: int64
# 3333846    3586
# Name: srch_destination_id, dtype: int64
# 2805042    9499
# Name: srch_destination_id, dtype: int64
# 1529665    21950
# 1770170    21950
# Name: srch_destination_id, dtype: int64
# 598676    4252
# Name: srch_destination_id, dtype: int64
# 1653296    4324
# 4346531    4324
# 4594909    4324
# Name: srch_destination_id, dtype: int64
# 391040    4400
# Name: srch_destination_id, dtype: int64
# 306910    5003
# Name: srch_destination_id, dtype: int64
# 1851025    6955
# Name: srch_destination_id, dtype: int64
# 848820     13066
# 1310837    13066
# 1616004    13066
# 2783187    13066
# 3905868    13066
# 4815309    13066
# Name: srch_destination_id, dtype: int64
# 4512272    14055
# Name: srch_destination_id, dtype: int64
# 819334     19955
# 4397069    19955
# Name: srch_destination_id, dtype: int64
# 2611194    9547
# Name: srch_destination_id, dtype: int64
# 3206738    3153
# Name: srch_destination_id, dtype: int64
# 2892142    10354
# 4935291    10354
# Name: srch_destination_id, dtype: int64
# 1907339    20808
# 2975589    20808
# Name: srch_destination_id, dtype: int64
# 751083     27530
# 796598     27530
# 1327348    27530
# 2498022    27530
# 3435362    27530
# Name: srch_destination_id, dtype: int64
# 877463     28310
# 4024747    28310
# Name: srch_destination_id, dtype: int64
# 3051988    26512
# 3463769    26512
# Name: srch_destination_id, dtype: int64
# 901966    7373
# Name: srch_destination_id, dtype: int64
# 1043810    11771
# 4289212    11771
# Name: srch_destination_id, dtype: int64
# 1839544    22784
# Name: srch_destination_id, dtype: int64
# 451411     8141
# 3690648    8141
# 4831091    8141
# Name: srch_destination_id, dtype: int64
# 1508885    9179
# 1969185    9179
# 2657274    9179
# Name: srch_destination_id, dtype: int64
# 2794038    25293
# Name: srch_destination_id, dtype: int64
# 1380834    10508
# 3174122    10508
# Name: srch_destination_id, dtype: int64
# 372287     20905
# 633288     20905
# 1124883    20905
# 1279915    20905
# 2854004    20905
# Name: srch_destination_id, dtype: int64
# 4225979    28254
# 4363928    28254
# Name: srch_destination_id, dtype: int64
# 1208066    9750
# Name: srch_destination_id, dtype: int64
# 1340648    13806
# 2175524    13806
# Name: srch_destination_id, dtype: int64
# 997027    21314
# Name: srch_destination_id, dtype: int64
# 2166237    10208
# Name: srch_destination_id, dtype: int64
# 796373     7553
# 1111796    7553
# 3538828    7553
# 3759272    7553
# 4696468    7553
# Name: srch_destination_id, dtype: int64
# 1931569    15979
# 4466059    15979
# Name: srch_destination_id, dtype: int64
# 6464       25427
# 352776     25427
# 783899     25427
# 1262423    25427
# 1564343    25427
# 2496831    25427
# 2559929    25427
# 2955494    25427
# 3012933    25427
# 3087857    25427
# 3781604    25427
# 3900175    25427
# 4247162    25427
# 4494397    25427
# 4594771    25427
# 4856649    25427
# Name: srch_destination_id, dtype: int64
# 3736815    16278
# 3763170    16278
# Name: srch_destination_id, dtype: int64
# 4714046    14972
# Name: srch_destination_id, dtype: int64
# 390178     67
# 1867072    67
# 3480194    67
# 3894000    67
# Name: srch_destination_id, dtype: int64
# 888598    3836
# Name: srch_destination_id, dtype: int64
# 464233     6800
# 2582720    6800
# Name: srch_destination_id, dtype: int64
# 2204494    17219
# Name: srch_destination_id, dtype: int64
# 1052411    20096
# Name: srch_destination_id, dtype: int64
# 515387    13092
# Name: srch_destination_id, dtype: int64
# 907786    23621
# Name: srch_destination_id, dtype: int64
# 1544273    23794
# Name: srch_destination_id, dtype: int64
# 4091038    10881
# Name: srch_destination_id, dtype: int64
# 3110638    27178
# Name: srch_destination_id, dtype: int64
# 747053     18191
# 2101364    18191
# 2424042    18191
# 3139158    18191
# 3877627    18191
# 4770487    18191
# Name: srch_destination_id, dtype: int64
# 3083267    18995
# Name: srch_destination_id, dtype: int64
# 6642       18191
# 413624     18191
# 499369     18191
# 556585     18191
# 678019     18191
# 822240     18191
# 1346253    18191
# 1473233    18191
# 1800823    18191
# 1900099    18191
# 2101365    18191
# 2201273    18191
# 2424043    18191
# 3071849    18191
# 3139159    18191
# 3384727    18191
# 3421579    18191
# 3877628    18191
# 4179960    18191
# 4851134    18191
# Name: srch_destination_id, dtype: int64
# 2656267    18995
# 3083268    18995
# Name: srch_destination_id, dtype: int64
# 2002464    5489
# Name: srch_destination_id, dtype: int64
# 3166411    8767
# 3823681    8767
# 4652568    8767
# Name: srch_destination_id, dtype: int64
# 1275096    3025
# 4459028    3025
# 4600379    3025
# Name: srch_destination_id, dtype: int64
# 2130286    3875
# 2194618    3875
# Name: srch_destination_id, dtype: int64
# 2885479    19882
# Name: srch_destination_id, dtype: int64
# 1654421    24877
# 2157940    24877
# 3016705    24877
# Name: srch_destination_id, dtype: int64
# 4796027    1436
# Name: srch_destination_id, dtype: int64
# 4740961    3772
# Name: srch_destination_id, dtype: int64
# 2865236    6833
# 3302140    6833
# Name: srch_destination_id, dtype: int64
# 3812586    17409
# Name: srch_destination_id, dtype: int64
# 823251     19898
# 1008065    19898
# 1105954    19898
# 1221220    19898
# 1426147    19898
# 1619603    19898
# 2225425    19898
# 2283240    19898
# 2441557    19898
# 2485790    19898
# 2513519    19898
# 2516731    19898
# 2687562    19898
# 2726885    19898
# 2939644    19898
# 3224472    19898
# 3924887    19898
# 4364750    19898
# Name: srch_destination_id, dtype: int64
# 590615     16841
# 3218770    16841
# 3378616    16841
# 4341881    16841
# 4893942    16841
# Name: srch_destination_id, dtype: int64
# 1420649    8518
# Name: srch_destination_id, dtype: int64
# 283296     10758
# 991087     10758
# 1360053    10758
# 1638114    10758
# 1663170    10758
# 2222838    10758
# 4017596    10758
# Name: srch_destination_id, dtype: int64
# 220346     10898
# 477965     10898
# 486856     10898
# 843460     10898
# 1224077    10898
# 1226540    10898
# 1412255    10898
# 2119024    10898
# 2394625    10898
# 2618209    10898
# 3359300    10898
# 3537130    10898
# 3733860    10898
# 3893081    10898
# Name: srch_destination_id, dtype: int64
# 329114    17200
# Name: srch_destination_id, dtype: int64
# 62147      21232
# 595313     21232
# 998387     21232
# 1348924    21232
# 1596677    21232
# 1761333    21232
# 1997308    21232
# 2803891    21232
# 2956048    21232
# 3738995    21232
# 3800969    21232
# 4550717    21232
# Name: srch_destination_id, dtype: int64
# 4167767    23906
# Name: srch_destination_id, dtype: int64
# 132769     27717
# 1881865    27717
# 2310199    27717
# 2937882    27717
# 3045357    27717
# 3141235    27717
# 3408986    27717
# 4179850    27717
# 4344956    27717
# Name: srch_destination_id, dtype: int64
# 23601      3821
# 727188     3821
# 1508559    3821
# 2545350    3821
# 4920982    3821
# Name: srch_destination_id, dtype: int64
# 2189166    4759
# Name: srch_destination_id, dtype: int64
# 1023096    8641
# Name: srch_destination_id, dtype: int64
# 1063852    10023
# 2746464    10023
# 3493807    10023
# 3682656    10023
# 3952394    10023
# 4309072    10023
# Name: srch_destination_id, dtype: int64
# 403247     19516
# 1208441    19516
# 2539164    19516
# 4649245    19516
# Name: srch_destination_id, dtype: int64
# 2791938    25671
# Name: srch_destination_id, dtype: int64
# 4612579    3212
# Name: srch_destination_id, dtype: int64
# 2603230    4374
# 3535750    4374
# Name: srch_destination_id, dtype: int64
# 707862    5883
# Name: srch_destination_id, dtype: int64
# 3259346    18024
# Name: srch_destination_id, dtype: int64
# 1351908    878
# Name: srch_destination_id, dtype: int64
# 3143565    1016
# Name: srch_destination_id, dtype: int64
# 702384     104
# 2735497    104
# 4693665    104
# Name: srch_destination_id, dtype: int64
# 3340422    2359
# 4593072    2359
# Name: srch_destination_id, dtype: int64
# 4637       14612
# 804601     14612
# 858687     14612
# 2588379    14612
# 2802637    14612
# 3004970    14612
# Name: srch_destination_id, dtype: int64
# 1468460    16132
# Name: srch_destination_id, dtype: int64
# 1585596    140
# Name: srch_destination_id, dtype: int64
# 3841351    21329
# Name: srch_destination_id, dtype: int64
# 1691022    1510
# 2135121    1510
# 2522640    1510
# 3932250    1510
# 4619259    1510
# Name: srch_destination_id, dtype: int64
# 9323       607
# 111616     607
# 408258     607
# 811164     607
# 3907667    607
# 4044242    607
# 4416053    607
# 4485473    607
# 4499165    607
# Name: srch_destination_id, dtype: int64
# 3960152    1173
# Name: srch_destination_id, dtype: int64
# 388483     3591
# 2963928    3591
# 4108014    3591
# Name: srch_destination_id, dtype: int64
# 1638412    5986
# 2917404    5986
# 3559268    5986
# Name: srch_destination_id, dtype: int64
# 1845181    7101
# Name: srch_destination_id, dtype: int64
# 569381     9129
# 1737459    9129
# Name: srch_destination_id, dtype: int64
# 435708     11213
# 1447771    11213
# 2724223    11213
# Name: srch_destination_id, dtype: int64
# 1898088    11537
# 3453845    11537
# Name: srch_destination_id, dtype: int64
# 2215607    17235
# Name: srch_destination_id, dtype: int64
# 189191     3602
# 218622     3602
# 3163826    3602
# Name: srch_destination_id, dtype: int64
# 1362148    9899
# 1392275    9899
# 1915195    9899
# 2001560    9899
# 3838170    9899
# Name: srch_destination_id, dtype: int64
# 14412      13870
# 44353      13870
# 55954      13870
# 74115      13870
# 119544     13870
# 344594     13870
# 444235     13870
# 454365     13870
# 1358099    13870
# 1374747    13870
# 1478076    13870
# 1604882    13870
# 1983229    13870
# 2258720    13870
# 2381759    13870
# 2407334    13870
# 2795520    13870
# 3045382    13870
# 3250303    13870
# 3304528    13870
# 3382727    13870
# 3506664    13870
# 3625847    13870
# 3823949    13870
# 3827700    13870
# 3975168    13870
# 4392486    13870
# 4559772    13870
# 4623173    13870
# 4679656    13870
# 4751041    13870
# 4797522    13870
# Name: srch_destination_id, dtype: int64
# 482489     15253
# 1074937    15253
# 1414789    15253
# 2090517    15253
# 2506122    15253
# 2683910    15253
# Name: srch_destination_id, dtype: int64
# 63961      15964
# 255729     15964
# 2419197    15964
# 2579730    15964
# 4066218    15964
# Name: srch_destination_id, dtype: int64
# 119717     16760
# 2160884    16760
# 3437955    16760
# 4244823    16760
# Name: srch_destination_id, dtype: int64
# 696282     23956
# 1808705    23956
# 2245218    23956
# Name: srch_destination_id, dtype: int64
# 1072619    25051
# Name: srch_destination_id, dtype: int64
# 960902     5784
# 2448860    5784
# Name: srch_destination_id, dtype: int64
# 3071416    24910
# 4952730    24910
# Name: srch_destination_id, dtype: int64
# 3321910    26411
# Name: srch_destination_id, dtype: int64
# 700342    6106
# Name: srch_destination_id, dtype: int64
# 786731    10907
# Name: srch_destination_id, dtype: int64
# 1930413    12072
# 3659097    12072
# Name: srch_destination_id, dtype: int64
# 266471     21350
# 1001722    21350
# Name: srch_destination_id, dtype: int64
# 910469     10374
# 1282251    10374
# 1674737    10374
# 2313945    10374
# 2465291    10374
# 4191694    10374
# 4282049    10374
# 4379216    10374
# Name: srch_destination_id, dtype: int64
# 626818     18102
# 651659     18102
# 709779     18102
# 788511     18102
# 1246243    18102
# 3558542    18102
# 4241926    18102
# Name: srch_destination_id, dtype: int64
# 1129490    20845
# Name: srch_destination_id, dtype: int64
# 1206485    3801
# Name: srch_destination_id, dtype: int64
# 9229       8857
# 1850070    8857
# Name: srch_destination_id, dtype: int64
# 4759336    325
# Name: srch_destination_id, dtype: int64
# 1801299    416
# Name: srch_destination_id, dtype: int64
# 72720      2142
# 692757     2142
# 1356942    2142
# 1866979    2142
# 1985876    2142
# 2065712    2142
# 2271603    2142
# 2292891    2142
# 2475840    2142
# 2816996    2142
# 3111169    2142
# 3977942    2142
# 4347660    2142
# 4893303    2142
# Name: srch_destination_id, dtype: int64
# 2523212    5919
# 4458166    5919
# Name: srch_destination_id, dtype: int64
# 3762275    9144
# Name: srch_destination_id, dtype: int64
# 4433904    9276
# Name: srch_destination_id, dtype: int64
# 2876629    24219
# 3121152    24219
# Name: srch_destination_id, dtype: int64
# 480401     417
# 1669275    417
# 3237455    417
# Name: srch_destination_id, dtype: int64
# 1508560    3821
# Name: srch_destination_id, dtype: int64
# 603113     7583
# 1477393    7583
# 1939893    7583
# 2061969    7583
# 3462272    7583
# 3664232    7583
# 4009755    7583
# 4440746    7583
# 4727049    7583
# Name: srch_destination_id, dtype: int64
# 2445709    15281
# 2663265    15281
# 3727318    15281
# Name: srch_destination_id, dtype: int64
# 2325007    16120
# 2853965    16120
# 3917078    16120
# Name: srch_destination_id, dtype: int64
# 733588    17124
# Name: srch_destination_id, dtype: int64
# 1173534    20994
# Name: srch_destination_id, dtype: int64
# 3053168    2932
# Name: srch_destination_id, dtype: int64
# 4138355    1175
# Name: srch_destination_id, dtype: int64
# 3395823    8159
# Name: srch_destination_id, dtype: int64
# 778787    21900
# Name: srch_destination_id, dtype: int64
# 1038125    4037
# Name: srch_destination_id, dtype: int64
# 1820642    11577
# 4896701    11577
# Name: srch_destination_id, dtype: int64
# 1383188    19633
# 2855330    19633
# Name: srch_destination_id, dtype: int64
# 861232     6146
# 1311234    6146
# Name: srch_destination_id, dtype: int64
# 4016394    11293
# Name: srch_destination_id, dtype: int64
# 3410030    27014
# Name: srch_destination_id, dtype: int64
# 3007545    18447
# 4751720    18447
# Name: srch_destination_id, dtype: int64
# 1610608    23495
# Name: srch_destination_id, dtype: int64
# 395349     7680
# 2384063    7680
# Name: srch_destination_id, dtype: int64
# 1785467    11228
# 2367111    11228
# 3539928    11228
# 4891636    11228
# Name: srch_destination_id, dtype: int64
# 279217     11392
# 895983     11392
# 2212940    11392
# Name: srch_destination_id, dtype: int64
# 670185     17252
# 1718240    17252
# 4755946    17252
# Name: srch_destination_id, dtype: int64
# 4761419    11099
# Name: srch_destination_id, dtype: int64
# 1162884    22848
# Name: srch_destination_id, dtype: int64
# 3632925    279
# Name: srch_destination_id, dtype: int64
# 1194302    976
# 1229672    976
# 2435252    976
# 4630505    976
# Name: srch_destination_id, dtype: int64
# 1384995    3535
# Name: srch_destination_id, dtype: int64
# 1044603    5300
# 4178715    5300
# Name: srch_destination_id, dtype: int64
# 636459    11580
# Name: srch_destination_id, dtype: int64
# 882543    15111
# Name: srch_destination_id, dtype: int64
# 2482077    19115
# Name: srch_destination_id, dtype: int64
# 198774     19709
# 668838     19709
# 751503     19709
# 852730     19709
# 1403774    19709
# 1761614    19709
# 1966408    19709
# 2798619    19709
# 3132769    19709
# 4508502    19709
# 4594636    19709
# Name: srch_destination_id, dtype: int64
# 15211      23904
# 1338805    23904
# 2196874    23904
# 2433160    23904
# 2542291    23904
# 2936755    23904
# 3273460    23904
# Name: srch_destination_id, dtype: int64
# 274261     5350
# 2867260    5350
# Name: srch_destination_id, dtype: int64
# 62504      8358
# 970800     8358
# 1068500    8358
# 1218830    8358
# 1994658    8358
# 2115352    8358
# 2242786    8358
# 2979500    8358
# 3042403    8358
# 3628489    8358
# 4271244    8358
# Name: srch_destination_id, dtype: int64
# 411846     18239
# 913419     18239
# 1496242    18239
# Name: srch_destination_id, dtype: int64
# 1649988    24110
# Name: srch_destination_id, dtype: int64
# 2594459    3154
# Name: srch_destination_id, dtype: int64
# 1457746    698
# 2337421    698
# 3494360    698
# 4136876    698
# 4245520    698
# 4429689    698
# Name: srch_destination_id, dtype: int64
# 3252080    4460
# 4232534    4460
# Name: srch_destination_id, dtype: int64
# 590822     16249
# 1917950    16249
# 3713614    16249
# Name: srch_destination_id, dtype: int64
# 3290805    19848
# Name: srch_destination_id, dtype: int64
# 894325    19255
# Name: srch_destination_id, dtype: int64
# 1073427    5063
# Name: srch_destination_id, dtype: int64
# 3109878    12192
# 4553588    12192
# Name: srch_destination_id, dtype: int64
# 2523494    26364
# Name: srch_destination_id, dtype: int64
# 4653477    3931
# Name: srch_destination_id, dtype: int64
# 160863     6475
# 188281     6475
# 201195     6475
# 455819     6475
# 541375     6475
# 602986     6475
# 849799     6475
# 1245902    6475
# 1304994    6475
# 1668433    6475
# 1941618    6475
# 2579012    6475
# 3180219    6475
# 3473754    6475
# 3516643    6475
# 4188459    6475
# 4269157    6475
# 4725197    6475
# Name: srch_destination_id, dtype: int64
# 3550612    14215
# Name: srch_destination_id, dtype: int64
# 288599     20983
# 2842791    20983
# Name: srch_destination_id, dtype: int64
# 309593     317
# 1968816    317
# Name: srch_destination_id, dtype: int64
# 1461431    5612
# 2437407    5612
# Name: srch_destination_id, dtype: int64
# 103626     17796
# 180474     17796
# 355061     17796
# 381629     17796
# 435339     17796
# 534905     17796
# 608877     17796
# 725128     17796
# 730943     17796
# 1248114    17796
# 1307499    17796
# 1346637    17796
# 1451272    17796
# 1888504    17796
# 1895205    17796
# 1951791    17796
# 2200642    17796
# 2256017    17796
# 2712164    17796
# 2760502    17796
# 2790884    17796
# 2943800    17796
# 3055622    17796
# 3103378    17796
# 3128763    17796
# 3128879    17796
# 3191032    17796
# 3229671    17796
# 3352987    17796
# 3372731    17796
# 3464963    17796
# 3923889    17796
# 4072042    17796
# 4116404    17796
# 4226404    17796
# 4237045    17796
# 4408737    17796
# 4532337    17796
# 4753977    17796
# Name: srch_destination_id, dtype: int64
# 132738     18357
# 446431     18357
# 453402     18357
# 709032     18357
# 749024     18357
# 882361     18357
# 3526176    18357
# 4699784    18357
# 4703127    18357
# 4880566    18357
# Name: srch_destination_id, dtype: int64
# 2480844    25974
# Name: srch_destination_id, dtype: int64
# 60683      28317
# 74937      28317
# 259079     28317
# 556319     28317
# 617105     28317
# 648888     28317
# 738364     28317
# 824881     28317
# 841541     28317
# 885312     28317
# 939504     28317
# 996545     28317
# 1569271    28317
# 1724877    28317
# 1771104    28317
# 1805609    28317
# 1983569    28317
# 2013177    28317
# 2338383    28317
# 2434721    28317
# 2538491    28317
# 2630318    28317
# 2689285    28317
# 2698899    28317
# 2752721    28317
# 2758096    28317
# 2899160    28317
# 2984293    28317
# 2999873    28317
# 3302241    28317
# 3418243    28317
# 3552194    28317
# 3961701    28317
# 3968254    28317
# 4053363    28317
# 4065665    28317
# 4133321    28317
# 4205875    28317
# 4307077    28317
# 4320223    28317
# 4428272    28317
# 4605815    28317
# 4844005    28317
# 4858124    28317
# 4933076    28317
# Name: srch_destination_id, dtype: int64
# 2785130    16126
# Name: srch_destination_id, dtype: int64
# 1229218    9904
# Name: srch_destination_id, dtype: int64
# 3292135    11616
# Name: srch_destination_id, dtype: int64
# 2431275    13078
# 2595614    13078
# Name: srch_destination_id, dtype: int64
# 882544    15111
# Name: srch_destination_id, dtype: int64
# 2482078    19115
# Name: srch_destination_id, dtype: int64
# 15212      23904
# 524498     23904
# 671291     23904
# 762094     23904
# 886055     23904
# 2535289    23904
# 3127151    23904
# 4130407    23904
# Name: srch_destination_id, dtype: int64
# 4249062    3265
# Name: srch_destination_id, dtype: int64
# 4592834    4606
# Name: srch_destination_id, dtype: int64
# 571796     6785
# 1760577    6785
# 4108200    6785
# 4196607    6785
# 4535718    6785
# Name: srch_destination_id, dtype: int64
# 2006465    21646
# Name: srch_destination_id, dtype: int64
# 2577529    22426
# Name: srch_destination_id, dtype: int64
# 304540     11413
# 2725533    11413
# 3697820    11413
# Name: srch_destination_id, dtype: int64
# 518978     14789
# 854872     14789
# 4859926    14789
# 4909584    14789
# Name: srch_destination_id, dtype: int64
# 179452     23047
# 233222     23047
# 559419     23047
# 862604     23047
# 1021996    23047
# 1072302    23047
# 1357111    23047
# 1467667    23047
# 1536467    23047
# 1601894    23047
# 1776239    23047
# 2081783    23047
# 2086673    23047
# 2293892    23047
# 2360139    23047
# 2361608    23047
# 2366900    23047
# 2427394    23047
# 3249766    23047
# 3613115    23047
# 3638659    23047
# 4248711    23047
# 4477723    23047
# 4841254    23047
# 4856298    23047
# Name: srch_destination_id, dtype: int64
# 23147      14469
# 1312803    14469
# Name: srch_destination_id, dtype: int64
# 51070    21361
# Name: srch_destination_id, dtype: int64
# 67155    27567
# Name: srch_destination_id, dtype: int64
# 2253920    8269
# Name: srch_destination_id, dtype: int64
# 428586    12018
# Name: srch_destination_id, dtype: int64
# 1136598    6507
# 1243381    6507
# 1450825    6507
# 4508545    6507
# 4690673    6507
# 4754537    6507
# Name: srch_destination_id, dtype: int64
# 2046659    9345
# Name: srch_destination_id, dtype: int64
# 2053057    11897
# Name: srch_destination_id, dtype: int64
# 42651      23605
# 165065     23605
# 324215     23605
# 503857     23605
# 857454     23605
# 925503     23605
# 981715     23605
# 1109998    23605
# 1468944    23605
# 1581367    23605
# 1606515    23605
# 1951387    23605
# 2101191    23605
# 2344519    23605
# 2446819    23605
# 2471684    23605
# 2949619    23605
# 3514194    23605
# 3722203    23605
# 3780287    23605
# 4126496    23605
# 4231454    23605
# 4546381    23605
# 4583697    23605
# 4641291    23605
# 4730998    23605
# 4876015    23605
# 4915611    23605
# Name: srch_destination_id, dtype: int64
# 85171      25426
# 502535     25426
# 918398     25426
# 941086     25426
# 973012     25426
# 1083272    25426
# 1158834    25426
# 1217467    25426
# 1281686    25426
# 1300160    25426
# 1426116    25426
# 1471644    25426
# 1529999    25426
# 1696280    25426
# 1926949    25426
# 2020317    25426
# 2165075    25426
# 2236063    25426
# 2331421    25426
# 2393635    25426
# 2437628    25426
# 2568115    25426
# 3080041    25426
# 3115383    25426
# 3404824    25426
# 3558655    25426
# 3571154    25426
# 3800224    25426
# 3860789    25426
# 3883357    25426
# 4003240    25426
# 4277391    25426
# 4361686    25426
# 4379233    25426
# 4692464    25426
# Name: srch_destination_id, dtype: int64
# 2448148    26372
# 3893780    26372
# 3974608    26372
# Name: srch_destination_id, dtype: int64
# 1105964    499
# 2849346    499
# 2882614    499
# Name: srch_destination_id, dtype: int64
# 1319984    14151
# Name: srch_destination_id, dtype: int64
# 3952735    415
# Name: srch_destination_id, dtype: int64
# 1133419    27605
# 1260176    27605
# 2082083    27605
# 2223277    27605
# Name: srch_destination_id, dtype: int64
# 2351904    2975
# Name: srch_destination_id, dtype: int64
# 1445087    7014
# Name: srch_destination_id, dtype: int64
# 45029    19414
# Name: srch_destination_id, dtype: int64
# 63880      4681
# 2327622    4681
# 3134184    4681
# 3432451    4681
# 4506712    4681
# Name: srch_destination_id, dtype: int64
# 2952778    5886
# Name: srch_destination_id, dtype: int64
# 232180    14943
# Name: srch_destination_id, dtype: int64
# 1691993    15026
# 2206576    15026
# Name: srch_destination_id, dtype: int64
# 2504391    16086
# Name: srch_destination_id, dtype: int64
# 2612470    25748
# Name: srch_destination_id, dtype: int64
# 203585    14464
# Name: srch_destination_id, dtype: int64
# 2074988    7723
# 2747066    7723
# Name: srch_destination_id, dtype: int64
# 38319      11205
# 1414148    11205
# 1468384    11205
# 1544825    11205
# 2038275    11205
# 2314432    11205
# 2457111    11205
# 2593618    11205
# 2684540    11205
# 2805333    11205
# 3509714    11205
# 4015019    11205
# 4176730    11205
# 4405822    11205
# 4486011    11205
# Name: srch_destination_id, dtype: int64
# 4065683    12710
# Name: srch_destination_id, dtype: int64
# 3457491    19176
# Name: srch_destination_id, dtype: int64
# 2031579    729
# 3066795    729
# Name: srch_destination_id, dtype: int64
# 3328262    28340
# 4519333    28340
# Name: srch_destination_id, dtype: int64
# 3183488    4727
# Name: srch_destination_id, dtype: int64
# 231326     8612
# 430723     8612
# 1001960    8612
# 1510603    8612
# 3226229    8612
# 3658094    8612
# 3898108    8612
# Name: srch_destination_id, dtype: int64
# 1637863    24731
# 3846219    24731
# Name: srch_destination_id, dtype: int64
# 2026052    11088
# Name: srch_destination_id, dtype: int64
# 2682706    2117
# 3110692    2117
# 4371260    2117
# Name: srch_destination_id, dtype: int64
# 774402    10433
# Name: srch_destination_id, dtype: int64
# 962465     15996
# 1362877    15996
# Name: srch_destination_id, dtype: int64
# 1346254    18191
# Name: srch_destination_id, dtype: int64
# 1463782    5329
# Name: srch_destination_id, dtype: int64
# 3560397    8718
# Name: srch_destination_id, dtype: int64
# 2289106    16947
# 3316394    16947
# Name: srch_destination_id, dtype: int64
# 1314853    14232
# 1451700    14232
# 2707968    14232
# 4280331    14232
# Name: srch_destination_id, dtype: int64
# 1909490    21327
# Name: srch_destination_id, dtype: int64
# 4311534    22405
# Name: srch_destination_id, dtype: int64
# 3669324    3442
# Name: srch_destination_id, dtype: int64
# 3011624    7677
# Name: srch_destination_id, dtype: int64
# 637306    8054
# Name: srch_destination_id, dtype: int64
# 1940309    8291
# 2369025    8291
# Name: srch_destination_id, dtype: int64
# 541050     8884
# 2708521    8884
# 3196455    8884
# 4374282    8884
# Name: srch_destination_id, dtype: int64
# 41696      17051
# 342741     17051
# 2301380    17051
# 2995377    17051
# 3344378    17051
# 4061019    17051
# Name: srch_destination_id, dtype: int64
# 1086868    18774
# 3465364    18774
# 3748098    18774
# Name: srch_destination_id, dtype: int64
# 2952975    21885
# 4211104    21885
# Name: srch_destination_id, dtype: int64
# 1721447    24887
# 3685532    24887
# 3893512    24887
# 4037810    24887
# Name: srch_destination_id, dtype: int64
# 2604048    24920
# Name: srch_destination_id, dtype: int64
# 124219     4463
# 416549     4463
# 837620     4463
# 939623     4463
# 3256306    4463
# 3770557    4463
# 3937984    4463
# 4802250    4463
# Name: srch_destination_id, dtype: int64
# 1579289    3620
# 3091106    3620
# Name: srch_destination_id, dtype: int64
# 2698146    8030
# Name: srch_destination_id, dtype: int64
# 55460    20106
# Name: srch_destination_id, dtype: int64
# 172678     21653
# 4495831    21653
# Name: srch_destination_id, dtype: int64
# 2661173    24994
# 3738013    24994
# Name: srch_destination_id, dtype: int64
# 1042857    4440
# 2324725    4440
# Name: srch_destination_id, dtype: int64
# 83298      14059
# 1639330    14059
# 1769286    14059
# 2859000    14059
# 3304370    14059
# Name: srch_destination_id, dtype: int64
# 1090608    22564
# Name: srch_destination_id, dtype: int64
# 1998627    4867
# 3937131    4867
# Name: srch_destination_id, dtype: int64
# 29827      9412
# 189328     9412
# 323285     9412
# 556078     9412
# 928291     9412
# 1245732    9412
# 1283076    9412
# 1586373    9412
# 1729293    9412
# 1802347    9412
# 1922229    9412
# 1982096    9412
# 2149910    9412
# 2334323    9412
# 2635284    9412
# 2682514    9412
# 2763068    9412
# 3153625    9412
# 3321494    9412
# 3448844    9412
# 3476615    9412
# 3512166    9412
# 3683220    9412
# 3825115    9412
# 3902485    9412
# 3943083    9412
# 4019661    9412
# 4262234    9412
# 4377598    9412
# 4548356    9412
# Name: srch_destination_id, dtype: int64
# 285495     11323
# 300284     11323
# 474663     11323
# 568831     11323
# 2002515    11323
# 2109908    11323
# 2149066    11323
# 2403713    11323
# 3426090    11323
# 3608961    11323
# 3813065    11323
# 3923802    11323
# 4234252    11323
# 4237758    11323
# 4364135    11323
# 4564837    11323
# 4809556    11323
# Name: srch_destination_id, dtype: int64
# 299262     21808
# 414100     21808
# 569026     21808
# 644620     21808
# 646021     21808
# 986732     21808
# 1072982    21808
# 1221994    21808
# 1234575    21808
# 1307542    21808
# 1636015    21808
# 1663806    21808
# 1719384    21808
# 1969734    21808
# 2103115    21808
# 2126701    21808
# 2192205    21808
# 2349336    21808
# 2406192    21808
# 2459343    21808
# 3054444    21808
# 3319523    21808
# 3405751    21808
# 3566142    21808
# 3641750    21808
# 4294787    21808
# 4326126    21808
# 4371573    21808
# 4538406    21808
# 4729603    21808
# 4894913    21808
# Name: srch_destination_id, dtype: int64
# 4419911    21856
# Name: srch_destination_id, dtype: int64
# 336850    26192
# 698974    26192
# Name: srch_destination_id, dtype: int64
# 1108446    15143
# Name: srch_destination_id, dtype: int64
# 1109280    17548
# 1701930    17548
# Name: srch_destination_id, dtype: int64
# 44004    1427
# Name: srch_destination_id, dtype: int64
# 924416    10553
# Name: srch_destination_id, dtype: int64
# 2301039    10616
# 2408758    10616
# 2567254    10616
# 4089214    10616
# Name: srch_destination_id, dtype: int64
# 1555959    16888
# Name: srch_destination_id, dtype: int64
# 2082892    17516
# 3638563    17516
# 3688018    17516
# 4834712    17516
# Name: srch_destination_id, dtype: int64
# 4391039    25723
# Name: srch_destination_id, dtype: int64
# 1943598    27012
# Name: srch_destination_id, dtype: int64
# 3993596    27741
# Name: srch_destination_id, dtype: int64
# 533538    13029
# Name: srch_destination_id, dtype: int64
# 4554422    17421
# Name: srch_destination_id, dtype: int64
# 468742     21150
# 867053     21150
# 997825     21150
# 2143375    21150
# 3808544    21150
# Name: srch_destination_id, dtype: int64
# 829017    8782
# Name: srch_destination_id, dtype: int64
# 1401579    26967
# Name: srch_destination_id, dtype: int64
# 2358272    25499
# Name: srch_destination_id, dtype: int64
# 2811099    5602
# 4162012    5602
# Name: srch_destination_id, dtype: int64
# 1360531    18987
# 4888139    18987
# Name: srch_destination_id, dtype: int64
# 3875037    9087
# 4830844    9087
# Name: srch_destination_id, dtype: int64
# 1609904    14167
# 2223362    14167
# 3614176    14167
# 3934568    14167
# Name: srch_destination_id, dtype: int64
# 169068     16570
# 1416350    16570
# 2572911    16570
# 2702508    16570
# 3052799    16570
# 3150926    16570
# 4160460    16570
# 4559467    16570
# 4840744    16570
# Name: srch_destination_id, dtype: int64
# 628136     22158
# 3995497    22158
# Name: srch_destination_id, dtype: int64
# 2729982    22393
# Name: srch_destination_id, dtype: int64
# 3427608    24992
# 3477473    24992
# Name: srch_destination_id, dtype: int64
# 163089     27615
# 934966     27615
# 1716003    27615
# 2096409    27615
# 2284571    27615
# 2424332    27615
# 3181699    27615
# 3953216    27615
# 4023589    27615
# 4025886    27615
# 4398519    27615
# 4648854    27615
# Name: srch_destination_id, dtype: int64
# 158109     6314
# 957835     6314
# 3801968    6314
# Name: srch_destination_id, dtype: int64
# 1129251    12582
# 3998227    12582
# Name: srch_destination_id, dtype: int64
# 4077215    17852
# Name: srch_destination_id, dtype: int64
# 2259619    21157
# Name: srch_destination_id, dtype: int64
# 2248522    2139
# 2741394    2139
# Name: srch_destination_id, dtype: int64
# 3191960    20249
# Name: srch_destination_id, dtype: int64
# 826873     28150
# 1580498    28150
# 3753934    28150
# 4098223    28150
# Name: srch_destination_id, dtype: int64
# 3502055    5078
# Name: srch_destination_id, dtype: int64
# 86832      23112
# 867921     23112
# 3339947    23112
# 3941329    23112
# 4416353    23112
# Name: srch_destination_id, dtype: int64
# 2214523    23495
# 3519333    23495
# 3571650    23495
# 3586709    23495
# Name: srch_destination_id, dtype: int64
# 4233418    1442
# Name: srch_destination_id, dtype: int64
# 1220601    8114
# 3275778    8114
# 4631889    8114
# Name: srch_destination_id, dtype: int64
# 394102     11814
# 812317     11814
# 1787921    11814
# 2087885    11814
# 3481190    11814
# 4138871    11814
# Name: srch_destination_id, dtype: int64
# 261447     17759
# 267023     17759
# 383275     17759
# 762323     17759
# 949165     17759
# 1026848    17759
# 1081795    17759
# 1289090    17759
# 1540066    17759
# 1566903    17759
# 1670385    17759
# 1888729    17759
# 2623353    17759
# 2898263    17759
# 3115263    17759
# 3632067    17759
# 3645062    17759
# 3718875    17759
# 4174567    17759
# 4198994    17759
# 4238501    17759
# 4381123    17759
# 4606374    17759
# 4795449    17759
# Name: srch_destination_id, dtype: int64
# 86245      18774
# 119620     18774
# 1166752    18774
# 1527869    18774
# 3125967    18774
# 3134497    18774
# 3158885    18774
# 4512161    18774
# Name: srch_destination_id, dtype: int64
# 12066      26037
# 136076     26037
# 514148     26037
# 899773     26037
# 1789421    26037
# 2559065    26037
# 2976335    26037
# 3219697    26037
# 3673717    26037
# 3715994    26037
# 4102648    26037
# 4116016    26037
# 4117465    26037
# 4473967    26037
# 4632182    26037
# 4665981    26037
# 4879113    26037
# 4947643    26037
# Name: srch_destination_id, dtype: int64
# 431847    27555
# Name: srch_destination_id, dtype: int64
# 2482001    11649
# Name: srch_destination_id, dtype: int64
# 208013     17106
# 2144892    17106
# Name: srch_destination_id, dtype: int64
# 393044     18757
# 554966     18757
# 3855348    18757
# 4393904    18757
# Name: srch_destination_id, dtype: int64
# 1152987    21715
# 1283548    21715
# 2829607    21715
# 4383219    21715
# Name: srch_destination_id, dtype: int64
# 1290256    1063
# 3537637    1063
# Name: srch_destination_id, dtype: int64
# 3135078    3423
# Name: srch_destination_id, dtype: int64
# 68159      13202
# 1286847    13202
# 2965335    13202
# 3307352    13202
# Name: srch_destination_id, dtype: int64
# 2063028    13911
# Name: srch_destination_id, dtype: int64
# 4236180    16529
# Name: srch_destination_id, dtype: int64
# 397432     25999
# 954554     25999
# 1635291    25999
# 1663753    25999
# 3385743    25999
# Name: srch_destination_id, dtype: int64
# 2557806    1343
# Name: srch_destination_id, dtype: int64
# 1852931    8531
# Name: srch_destination_id, dtype: int64
# 77448    26571
# Name: srch_destination_id, dtype: int64
# 2813241    27171
# Name: srch_destination_id, dtype: int64
# 212176     982
# 707418     982
# 1273709    982
# 1464184    982
# 1553051    982
# 1923191    982
# 2050417    982
# 2860702    982
# 3442584    982
# 4782922    982
# Name: srch_destination_id, dtype: int64
# 71851      4858
# 1551070    4858
# 2626083    4858
# 4678066    4858
# Name: srch_destination_id, dtype: int64
# 479441     7306
# 531183     7306
# 605662     7306
# 658940     7306
# 906256     7306
# 1895563    7306
# 2269000    7306
# 2378502    7306
# 2398011    7306
# 2659284    7306
# 2949187    7306
# 3456666    7306
# 3864068    7306
# 4389709    7306
# 4401464    7306
# 4719683    7306
# 4927717    7306
# Name: srch_destination_id, dtype: int64
# 47463      18825
# 84373      18825
# 1915920    18825
# 2206848    18825
# 2508344    18825
# 2911227    18825
# 3049474    18825
# 3247187    18825
# 3302323    18825
# 3530265    18825
# 3563584    18825
# 4110409    18825
# 4139760    18825
# 4343502    18825
# 4394137    18825
# 4620251    18825
# Name: srch_destination_id, dtype: int64
# 3335629    24996
# 3359207    24996
# Name: srch_destination_id, dtype: int64
# 682723     24042
# 904773     24042
# 1038576    24042
# 1064669    24042
# 1486847    24042
# 1597319    24042
# 2709855    24042
# 3288406    24042
# 3301475    24042
# 3439640    24042
# 3588913    24042
# 4087971    24042
# 4197117    24042
# 4530168    24042
# 4853697    24042
# Name: srch_destination_id, dtype: int64
# 442846     8590
# 598101     8590
# 794301     8590
# 817122     8590
# 1058184    8590
# 1212626    8590
# 1598672    8590
# 2047653    8590
# 3598060    8590
# 4167399    8590
# 4200650    8590
# 4574664    8590
# Name: srch_destination_id, dtype: int64
# 664376     9221
# 1019470    9221
# 2216985    9221
# 2539762    9221
# 2793575    9221
# 3714822    9221
# 4405067    9221
# Name: srch_destination_id, dtype: int64
# 3292136    11616
# Name: srch_destination_id, dtype: int64
# 2431276    13078
# 2595615    13078
# Name: srch_destination_id, dtype: int64
# 1607757    15226
# Name: srch_destination_id, dtype: int64
# 3483552    15553
# 4832252    15553
# Name: srch_destination_id, dtype: int64
# 4671536    18850
# Name: srch_destination_id, dtype: int64
# 4671712    20689
# Name: srch_destination_id, dtype: int64
# 1273131    21171
# Name: srch_destination_id, dtype: int64
# 3289258    23190
# Name: srch_destination_id, dtype: int64
# 3202224    23677
# Name: srch_destination_id, dtype: int64
# 147714     23904
# 796284     23904
# 886056     23904
# 1314434    23904
# 1709345    23904
# 2091289    23904
# 2151815    23904
# 2519935    23904
# 3273461    23904
# 4305919    23904
# 4306421    23904
# Name: srch_destination_id, dtype: int64
# 352945     7848
# 2684449    7848
# 2715820    7848
# 4794996    7848
# Name: srch_destination_id, dtype: int64
# 3287690    12082
# Name: srch_destination_id, dtype: int64
# 2695582    13868
# Name: srch_destination_id, dtype: int64
# 2353165    16937
# Name: srch_destination_id, dtype: int64
# 2517080    7573
# Name: srch_destination_id, dtype: int64
# 133227     7770
# 1648842    7770
# 2836164    7770
# 2959871    7770
# 3048184    7770
# 4051253    7770
# 4273141    7770
# 4687697    7770
# Name: srch_destination_id, dtype: int64
# 26282      23495
# 2462673    23495
# 2727498    23495
# 3657410    23495
# 3898675    23495
# 4024568    23495
# Name: srch_destination_id, dtype: int64
# 598677    4252
# Name: srch_destination_id, dtype: int64
# 391041    4400
# Name: srch_destination_id, dtype: int64
# 1851026    6955
# Name: srch_destination_id, dtype: int64
# 848821     13066
# 1310838    13066
# 1616005    13066
# 3905869    13066
# 4815310    13066
# Name: srch_destination_id, dtype: int64
# 4512273    14055
# Name: srch_destination_id, dtype: int64
# 4397070    19955
# Name: srch_destination_id, dtype: int64
# 4556328    955
# Name: srch_destination_id, dtype: int64
# 1572550    3217
# 1700164    3217
# 1810853    3217
# 1951873    3217
# 2699179    3217
# 2728727    3217
# 2756584    3217
# 3192113    3217
# 4283756    3217
# 4633333    3217
# Name: srch_destination_id, dtype: int64
# 4772702    11499
# Name: srch_destination_id, dtype: int64
# 1112552    14744
# 2429780    14744
# 2991789    14744
# Name: srch_destination_id, dtype: int64
# 3485948    7234
# Name: srch_destination_id, dtype: int64
# 1228749    1547
# Name: srch_destination_id, dtype: int64
# 3717901    9483
# Name: srch_destination_id, dtype: int64
# 2345721    10251
# Name: srch_destination_id, dtype: int64
# 307700     15620
# 876059     15620
# 1058684    15620
# 1256638    15620
# 1367677    15620
# 1509427    15620
# 1600233    15620
# 2162326    15620
# Name: srch_destination_id, dtype: int64
# 2184625    18180
# Name: srch_destination_id, dtype: int64
# 219925    234
# Name: srch_destination_id, dtype: int64
# 3089606    2124
# Name: srch_destination_id, dtype: int64
# 198857     2518
# 312783     2518
# 955191     2518
# 1235275    2518
# 1726193    2518
# 1915609    2518
# 2433651    2518
# 2719265    2518
# 2744020    2518
# 3343367    2518
# 3347573    2518
# 3766945    2518
# 4076207    2518
# 4194533    2518
# 4377565    2518
# 4460398    2518
# 4468322    2518
# 4799010    2518
# Name: srch_destination_id, dtype: int64
# 41899      11846
# 65671      11846
# 348237     11846
# 869999     11846
# 1300613    11846
# 1585190    11846
# 1688647    11846
# 1759287    11846
# 2131192    11846
# 2161971    11846
# 2449180    11846
# 3016410    11846
# 3051105    11846
# 3330810    11846
# 3436206    11846
# 3512993    11846
# 3757773    11846
# 3764938    11846
# 3807307    11846
# 4034436    11846
# 4092603    11846
# 4101224    11846
# 4125619    11846
# Name: srch_destination_id, dtype: int64
# 133860     18992
# 4568377    18992
# Name: srch_destination_id, dtype: int64
# 2629923    20515
# 2651327    20515
# ...
# Name: srch_destination_id, dtype: int64
# 2603995    22406
# 3125146    22406
# Name: srch_destination_id, dtype: int64
# 585020     22608
# 587422     22608
# 1292073    22608
# 2561957    22608
# 2698120    22608
# 3030489    22608
# 3169813    22608
# 3262581    22608
# 3281093    22608
# 3395201    22608
# 3803941    22608
# 3849694    22608
# 4366947    22608
# 4393664    22608
# 4870249    22608
# Name: srch_destination_id, dtype: int64
# 2759450    26380
# Name: srch_destination_id, dtype: int64
# 2619832    4744
# Name: srch_destination_id, dtype: int64
# 1981988    1447
# Name: srch_destination_id, dtype: int64
# 23917      11507
# 236658     11507
# 454463     11507
# 890573     11507
# 1165394    11507
# 1218803    11507
# 2714188    11507
# 3048995    11507
# 4801486    11507
# Name: srch_destination_id, dtype: int64
# 4269577    26796
# Name: srch_destination_id, dtype: int64
# 820714     6948
# 1240423    6948
# 1326863    6948
# 1341814    6948
# 1451865    6948
# 1727384    6948
# 1846335    6948
# 2501101    6948
# 2585653    6948
# 3536501    6948
# 3678957    6948
# 3885060    6948
# 3904296    6948
# 3927591    6948
# 4123987    6948
# 4406767    6948
# 4498978    6948
# 4618428    6948
# 4927862    6948
# Name: srch_destination_id, dtype: int64
# 4206985    10450
# Name: srch_destination_id, dtype: int64
# 3220151    12034
# 4813345    12034
# Name: srch_destination_id, dtype: int64
# 4867376    14274
# Name: srch_destination_id, dtype: int64
# 301450     17311
# 404915     17311
# 717323     17311
# 1165361    17311
# 1255864    17311
# 1542125    17311
# 2322829    17311
# 2412468    17311
# 3728023    17311
# 3759531    17311
# 3970792    17311
# 4259809    17311
# Name: srch_destination_id, dtype: int64
# 1884098    26832
# Name: srch_destination_id, dtype: int64
# 4330463    22501
# Name: srch_destination_id, dtype: int64
# 3586712    23495
# Name: srch_destination_id, dtype: int64
# 1259154    3474
# Name: srch_destination_id, dtype: int64
# 607643    20833
# Name: srch_destination_id, dtype: int64
# 1071947    25453
# 2549305    25453
# 2986644    25453
# Name: srch_destination_id, dtype: int64
# 724392    1572
# Name: srch_destination_id, dtype: int64
# 2174474    3611
# 2474117    3611
# Name: srch_destination_id, dtype: int64
# 125349     6123
# 2383746    6123
# Name: srch_destination_id, dtype: int64
# 190077     10737
# 624444     10737
# 916508     10737
# 1529833    10737
# 3491837    10737
# 3876028    10737
# Name: srch_destination_id, dtype: int64
# 2576859    11355
# 4867345    11355
# Name: srch_destination_id, dtype: int64
# 193324    14493
# Name: srch_destination_id, dtype: int64
# 929692     24686
# 1353550    24686
# 4367022    24686
# 4892030    24686
# Name: srch_destination_id, dtype: int64
# 263163    4016
# Name: srch_destination_id, dtype: int64
# 1037359    6005
# 1263428    6005
# 1644492    6005
# 2448356    6005
# 3880250    6005
# Name: srch_destination_id, dtype: int64
# 1828086    1954
# Name: srch_destination_id, dtype: int64
# 767626     4624
# 3640702    4624
# 3672806    4624
# Name: srch_destination_id, dtype: int64
# 1793336    22861
# Name: srch_destination_id, dtype: int64
# 2842976    26504
# Name: srch_destination_id, dtype: int64
# 54288      1718
# 1886207    1718
# Name: srch_destination_id, dtype: int64
# 3646623    9327
# Name: srch_destination_id, dtype: int64
# 2999286    6903
# Name: srch_destination_id, dtype: int64
# 2508610    1116
# Name: srch_destination_id, dtype: int64
# 2926740    3108
# 3079498    3108
# 3833319    3108
# Name: srch_destination_id, dtype: int64
# 4355035    13367
# Name: srch_destination_id, dtype: int64
# 1665060    2274
# 1749985    2274
# 1921270    2274
# 1941880    2274
# 3380722    2274
# 3633771    2274
# 3757893    2274
# 4020721    2274
# 4082430    2274
# 4187400    2274
# 4528486    2274
# 4936908    2274
# Name: srch_destination_id, dtype: int64
# 523749     9068
# 1281182    9068
# 1769721    9068
# Name: srch_destination_id, dtype: int64
# 2211912    10086
# 3927285    10086
# Name: srch_destination_id, dtype: int64
# 1660083    12756
# Name: srch_destination_id, dtype: int64
# 1218067    15555
# Name: srch_destination_id, dtype: int64
# 2439482    16785
# Name: srch_destination_id, dtype: int64
# 1974819    18552
# 1977035    18552
# 4012245    18552
# 4203487    18552
# 4345879    18552
# Name: srch_destination_id, dtype: int64
# 794076     18774
# 1757809    18774
# 4476110    18774
# Name: srch_destination_id, dtype: int64
# 1773918    24052
# Name: srch_destination_id, dtype: int64
# 2434948    14266
# 2450357    14266
# 2467091    14266
# 2759584    14266
# 2940295    14266
# 3869487    14266
# 3885548    14266
# 3976387    14266
# Name: srch_destination_id, dtype: int64
# 1191665    14679
# Name: srch_destination_id, dtype: int64
# 3844136    21722
# Name: srch_destination_id, dtype: int64
# 534655     23177
# 644692     23177
# 3916381    23177
# Name: srch_destination_id, dtype: int64
# 3204406    16331
# Name: srch_destination_id, dtype: int64
# 55923      6948
# 166184     6948
# 352321     6948
# 647896     6948
# 883107     6948
# 1094030    6948
# 1165726    6948
# 1240424    6948
# 1451866    6948
# 1490920    6948
# 1516721    6948
# 1727385    6948
# 1755823    6948
# 2336964    6948
# 2467532    6948
# 2475620    6948
# 2490550    6948
# 2501102    6948
# 2536400    6948
# 2585654    6948
# 2899227    6948
# 3001877    6948
# 3096036    6948
# 3177506    6948
# 3338319    6948
# 3536502    6948
# 3580277    6948
# 3742640    6948
# 3745428    6948
# 3853197    6948
# 3885061    6948
# 3888023    6948
# 3927592    6948
# 3995972    6948
# 4053886    6948
# 4174481    6948
# 4406768    6948
# 4498979    6948
# 4533692    6948
# 4600653    6948
# 4632413    6948
# Name: srch_destination_id, dtype: int64
# 3220152    12034
# 4813346    12034
# Name: srch_destination_id, dtype: int64
# 1888118    13622
# 4418159    13622
# Name: srch_destination_id, dtype: int64
# 1406009    14274
# 4726262    14274
# 4867377    14274
# Name: srch_destination_id, dtype: int64
# 325488     17311
# 596110     17311
# 619727     17311
# 717324     17311
# 817089     17311
# 1255865    17311
# 2016411    17311
# 2264002    17311
# 2412469    17311
# 3747263    17311
# 3759532    17311
# 4259810    17311
# Name: srch_destination_id, dtype: int64
# 2203753    25574
# Name: srch_destination_id, dtype: int64
# 2644158    27664
# Name: srch_destination_id, dtype: int64
# 681009     1815
# 1275507    1815
# 2277228    1815
# 3128551    1815
# Name: srch_destination_id, dtype: int64
# 786546     2304
# 3624951    2304
# Name: srch_destination_id, dtype: int64
# 911911    11946
# Name: srch_destination_id, dtype: int64
# 387565     5245
# 4524168    5245
# 4541774    5245
# Name: srch_destination_id, dtype: int64
# 1891307    5363
# 4751163    5363
# Name: srch_destination_id, dtype: int64
# 961527     12948
# 1064216    12948
# 2538674    12948
# Name: srch_destination_id, dtype: int64
# 4175231    18043
# Name: srch_destination_id, dtype: int64
# 1910760    1083
# Name: srch_destination_id, dtype: int64
# 1734155    8750
# Name: srch_destination_id, dtype: int64
# 3038201    13355
# 4724558    13355
# 4803171    13355
# 4820683    13355
# Name: srch_destination_id, dtype: int64
# 3092330    19626
# Name: srch_destination_id, dtype: int64
# 271005     20268
# 535263     20268
# 745694     20268
# 1226573    20268
# 1344521    20268
# 1482494    20268
# 1649959    20268
# 1871260    20268
# 2008991    20268
# 2639956    20268
# 3120752    20268
# 3130417    20268
# 3148730    20268
# 3288233    20268
# 3297390    20268
# 3907425    20268
# 3940637    20268
# 4608756    20268
# Name: srch_destination_id, dtype: int64
# 421227     20459
# 568545     20459
# 925716     20459
# 1027350    20459
# 1999040    20459
# 3085834    20459
# 3326814    20459
# 4244297    20459
# 4419786    20459
# 4674954    20459
# 4908740    20459
# Name: srch_destination_id, dtype: int64
# 772195    23125
# Name: srch_destination_id, dtype: int64
# 3371679    23786
# Name: srch_destination_id, dtype: int64
# 1799855    25267
# 3120400    25267
# Name: srch_destination_id, dtype: int64
# 31601      25479
# 64918      25479
# 85907      25479
# 122705     25479
# 242643     25479
# 244080     25479
# 280635     25479
# 353058     25479
# 379776     25479
# 441984     25479
# 514097     25479
# 545889     25479
# 1028855    25479
# 1260920    25479
# 1414447    25479
# 1842688    25479
# 1954337    25479
# 1973977    25479
# 2257715    25479
# 2303942    25479
# 2479325    25479
# 2540462    25479
# 2577714    25479
# 2603868    25479
# 2699123    25479
# 2743220    25479
# 2754325    25479
# 2943896    25479
# 2999118    25479
# 3005048    25479
# 3297439    25479
# 3638606    25479
# 3957135    25479
# 4080217    25479
# 4147868    25479
# 4148952    25479
# 4199362    25479
# 4360441    25479
# 4522305    25479
# 4556897    25479
# 4586626    25479
# 4757453    25479
# 4838301    25479
# Name: srch_destination_id, dtype: int64
# 1065849    2032
# Name: srch_destination_id, dtype: int64
# 1479363    11936
# Name: srch_destination_id, dtype: int64
# 523480    18841
# Name: srch_destination_id, dtype: int64
# 3555585    27149
# 4191377    27149
# Name: srch_destination_id, dtype: int64
# 4285157    20508
# Name: srch_destination_id, dtype: int64
# 223119     8159
# 2100628    8159
# 3395826    8159
# 4112688    8159
# 4420931    8159
# 4868897    8159
# Name: srch_destination_id, dtype: int64
# 203688     13292
# 1460309    13292
# 1729939    13292
# 1781188    13292
# 2104435    13292
# 2546794    13292
# 3370999    13292
# 3371796    13292
# 3436232    13292
# 4026394    13292
# 4139731    13292
# 4363877    13292
# 4395107    13292
# 4417900    13292
# 4537321    13292
# 4801683    13292
# Name: srch_destination_id, dtype: int64
# 230675     23095
# 4412913    23095
# Name: srch_destination_id, dtype: int64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims)
#    2289         try:
# -> 2290             amax = a.max
#    2291         except AttributeError:
#
# AttributeError: 'list' object has no attribute 'max'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-3854bbffb29f> in <module>()
#       9     print(dest)
#      10
# ---> 11 _val.groupby(["prop_id", "srch_destination_id"]).apply(series_add_est_pos)
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in apply(self, func, *args, **kwargs)
#     692         # ignore SettingWithCopy here in case the user mutates
#     693         with option_context('mode.chained_assignment', None):
# --> 694             return self._python_apply_general(f)
#     695
#     696     def _python_apply_general(self, f):
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in _python_apply_general(self, f)
#     696     def _python_apply_general(self, f):
#     697         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 698                                                    self.axis)
#     699
#     700         return self._wrap_applied_output(
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in apply(self, f, data, axis)
#    1593                 hasattr(splitter, 'fast_apply') and axis == 0):
#    1594             try:
# -> 1595                 values, mutated = splitter.fast_apply(f, group_keys)
#    1596                 return group_keys, values, mutated
#    1597             except (lib.InvalidApply):
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/groupby.py in fast_apply(self, f, names)
#    4061
#    4062         sdata = self._get_sorted_data()
# -> 4063         results, mutated = lib.apply_frame_axis0(sdata, f, names, starts, ends)
#    4064
#    4065         return results, mutated
#
# pandas/src/reduce.pyx in pandas.lib.apply_frame_axis0 (pandas/lib.c:43057)()
#
# <ipython-input-5-3854bbffb29f> in series_add_est_pos(s)
#       7 def series_add_est_pos(s):
#       8     dest = s.srch_destination_id
# ----> 9     print(dest)
#      10
#      11 _val.groupby(["prop_id", "srch_destination_id"]).apply(series_add_est_pos)
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/base.py in __str__(self)
#      48
#      49         if compat.PY3:
# ---> 50             return self.__unicode__()
#      51         return self.__bytes__()
#      52
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/series.py in __unicode__(self)
#    1010
#    1011         self.to_string(buf=buf, name=self.name, dtype=self.dtype,
# -> 1012                        max_rows=max_rows)
#    1013         result = buf.getvalue()
#    1014
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/series.py in to_string(self, buf, na_rep, float_format, header, index, length, dtype, name, max_rows)
#    1051         the_repr = self._get_repr(float_format=float_format, na_rep=na_rep,
#    1052                                   header=header, index=index, length=length,
# -> 1053                                   dtype=dtype, name=name, max_rows=max_rows)
#    1054
#    1055         # catch contract violations
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/core/series.py in _get_repr(self, name, header, index, length, dtype, na_rep, float_format, max_rows)
#    1079                                         float_format=float_format,
#    1080                                         max_rows=max_rows)
# -> 1081         result = formatter.to_string()
#    1082
#    1083         # TODO: following check prob. not neces.
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/formats/format.py in to_string(self)
#     240             return 'Series([], ' + footer + ')'
#     241
# --> 242         fmt_index, have_header = self._get_formatted_index()
#     243         fmt_values = self._get_formatted_values()
#     244
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/formats/format.py in _get_formatted_index(self)
#     226         else:
#     227             have_header = index.name is not None
# --> 228             fmt_index = index.format(name=True)
#     229         return fmt_index, have_header
#     230
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/indexes/base.py in format(self, name, formatter, **kwargs)
#    1596             return header + list(self.map(formatter))
#    1597
# -> 1598         return self._format_with_header(header, **kwargs)
#    1599
#    1600     def _format_with_header(self, header, na_rep='NaN', **kwargs):
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/indexes/base.py in _format_with_header(self, header, na_rep, **kwargs)
#    1620
#    1621         else:
# -> 1622             result = _trim_front(format_array(values, None, justify='left'))
#    1623         return header + result
#    1624
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/formats/format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#    1932                         space=space, justify=justify, decimal=decimal)
#    1933
# -> 1934     return fmt_obj.get_result()
#    1935
#    1936
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/formats/format.py in get_result(self)
#    1952     def get_result(self):
#    1953         fmt_values = self._format_strings()
# -> 1954         return _make_fixed_width(fmt_values, self.justify)
#    1955
#    1956     def _format_strings(self):
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/pandas/formats/format.py in _make_fixed_width(strings, justify, minimum, adj)
#    2388         adj = _get_adjustment()
#    2389
# -> 2390     max_len = np.max([adj.len(x) for x in strings])
#    2391
#    2392     if minimum is not None:
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/numpy/core/fromnumeric.py in amax(a, axis, out, keepdims)
#    2291         except AttributeError:
#    2292             return _methods._amax(a, axis=axis,
# -> 2293                                 out=out, **kwargs)
#    2294         return amax(axis=axis, out=out, **kwargs)
#    2295     else:
#
# /Users/richard/anaconda3/envs/py35/lib/python3.5/site-packages/numpy/core/_methods.py in _amax(a, axis, out, keepdims)
#      24 # small reductions
#      25 def _amax(a, axis=None, out=None, keepdims=False):
# ---> 26     return umr_maximum(a, axis, None, out, keepdims)
#      27
#      28 def _amin(a, axis=None, out=None, keepdims=False):
#
# KeyboardInterrupt:

# %%
in_train.columns
